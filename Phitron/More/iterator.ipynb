# %%
s = {10,20,30,40,50}

s_iter = iter(s)

# print(type(s_iter))

print(next(s_iter))
print(next(s_iter))
print(next(s_iter))
print(next(s_iter))
print(next(s_iter))
print("----------------------")

# uses iterator internally
for i in s:
    print(i)

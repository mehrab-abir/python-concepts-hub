# %% [markdown]
# Filter integers divisible by 3 but not divisible by 5

# %%
nums = list(map(int,input("Enter numbers: ").split()))

filtered = list(filter(lambda x: x % 3 ==0 and x % 5 != 0, nums))

print(filtered)
# Out:
# [3, 9, 18, 21]

# %% [markdown]
# Write a function compute(a, b) that:
# Returns (a² + b²) / (a - b)

# %%
def comput(a,b):
    try:
        divider = a-b;
        result = (a**2+b**2)/divider
        return result
    except ZeroDivisionError:
        print("Error: Divider can not be zero")
        
print(comput(10,5))
# Out:
# 25.0

# %% [markdown]
# Write a Python program that reads a text file and finds the most frequently occurring word.

# %%
try:
    with open("./data.txt",'r') as file:
        content = file.read().lower()
        # print(content)
        
        words = content.split()
        
        print(words)
        
        word_count = {}
        
        for word in words:
            word_count[word] = word_count.get(word,0) + 1
        
        maxOccuringWord = None
        maxCount = 0
        
        for key,value in word_count.items():
            if value > maxCount:
                maxCount = value
                maxOccuringWord = key
        
        print(f"Maximum ocurring word: {maxOccuringWord} ==> {maxCount}")

        
except Exception as e:
    print(e)
finally:
    print("\nDone!")
# Out:
# ['loki', 'captain', 'thor', 'captain', 'strange', 'hulk', 'thor', 'captain', 'captain', 'thor', 'captain', 'captain']
# Maximum ocurring word: captain ==> 6
#
# Done!

# %% [markdown]
# Write a program that converts a sentence into a list representing the length of each word. Ignore extra spaces

# %%
sentence = input("Enter the sentence: ")

wordsArr = sentence.split()
print(wordsArr)

lengthArr = list(map(lambda word : len(word),wordsArr))
print(lengthArr)
# Out:
# ['Machine', 'learning', 'is', 'fun']
# [7, 8, 2, 3]

# %% [markdown]
# Mirror Number

# %%
num = int(input("Enter the number: "))

original_num = num;
reversed_num = 0;

while num != 0:
    singleDigit = num % 10;
    reversed_num = reversed_num * 10 + singleDigit
    num = num // 10

if(reversed_num == original_num):
    print("Mirror Number")
else:
    print("Not Mirror Number")
# Out:
# Not Mirror Number

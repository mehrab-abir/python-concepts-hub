# %% [markdown]
# There is an array of  integers. There are also  disjoint sets,  and , each containing  integers. You like all the integers in set  and dislike all the integers in set . Your initial happiness is . For each  integer in the array, if , you add  to your happiness. If , you add  to your happiness. Otherwise, your happiness does not change. Output your final happiness at the end.
#
# Note: Since  and  are sets, they have no repeated elements. However, the array might contain duplicate elements.

# %%
array_size, set_size = map(int,(input("Array size: ").split()))
arr = list(map(int,input("Enter the array elements: ").split()))

set_a_array = list(map(int,input("Set A elements: ").split()))
set_b_array = list(map(int,input("Set B elements: ").split()))

set_a = set(set_a_array)
set_b = set(set_b_array)

happiness = 0

for i in arr:
    if(i in set_a):
        happiness += 1
    if(i in set_b):
        happiness -= 1
        
print(f"Final Happiness: {happiness}")
# Out:
# Final Happiness: 2

# %% [markdown]
# Given an integer, , and  space-separated integers as input, create a tuple, , of those  integers. Then compute and print the result of hash()

# %%
arr_size = int(input("Array Size: "))
arr = list(map(int,input("Enter the elements: ").split()))

tple = tuple(arr)

hashed = hash(tple)

print(hashed)
# Out:
# -3550055125485641917
